# %%
import pandas as pd

# %%
# loading clean data for analysis

# %%
df = pd.read_csv("../Roja Krishna/Book1.csv")

print(df.to_string())
# Out:
#   Height Weight  Age Grip Strength Frailty
# 0  65.8    112   30            30       N
# 1  71.5    136   19            31       N
# 2  69.4    153   45            29       N
# 3  68.2    142   22            28       Y
# 4  67.8    144   29            24       Y
# 5  68.7    123   50            26       N
# 6  69.8    141   51            22       Y
# 7  70.1    136   23            20       Y
# 8  67.9    112   17            19       N
# 9  66.8    120   39            31       N

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Height         10 non-null     object
#  1   Weight         10 non-null     object
#  2   Age            10 non-null     object
#  3   Grip Strength  10 non-null     object
#  4   Frailty        10 non-null     object
# dtypes: object(5)
# memory usage: 532.0+ bytes

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# below graph shows the distribution of Age in the given data

# %%
ax=sns.distplot(df['Age'], kde = False, color ='blue', bins = 30)
fig=ax.get_figure()
fig.savefig("../Roja Krishna/Age_Distibution.png")
# Out:
# C:\Users\Roja Krishna\AppData\Local\Temp\ipykernel_13212\3808188612.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(df['Age'], kde = False, color ='blue', bins = 30)

# %%
# below graph shows the distribution of Gripstrength in the given data

# %%
ax=sns.distplot(df['Grip Strength'], kde = False, color ='green', bins = 30)
fig=ax.get_figure()
fig.savefig("../Roja Krishna/Grip_Strength_Distibution.png")
# Out:
# C:\Users\Roja Krishna\AppData\Local\Temp\ipykernel_13212\2914162441.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(df['Grip Strength'], kde = False, color ='green', bins = 30)

# %%
#below graph shows how the gripstrength increases with age and decreases after certain age

# %%
ax = df.plot.scatter(x='Age',y='Grip Strength')
fig=ax.get_figure()
fig.savefig("../Roja Krishna/Grip_Strength_Age_Relation.png")

# %%
# below graph shows the relation between gripstrength and weight and how iut varies on weight.

# %%
ax = df.plot.scatter(x='Weight',y='Grip Strength')
fig=ax.get_figure()
fig.savefig("../Roja Krishna/GripStrength_Weight_Relation.png")
